# %% [markdown]
# # Nhật ký bài liệt kê tổ hợp

# %%
# %run ToHop.py

# %%
docfile('ToHop1.inp')
# Out:
# ['5 2\n', 'A\n', 'B\n', 'C\n', 'D\n', 'E']

# %%
docfile('ToHop2.inp')
# Out:
# (6, 4, ['one', 'two', 'three', 'four', 'five', 'six'])

# %%
docfile('ToHop1.inp')
# Out:
# (5, 3, ['A', 'B', 'C', 'D', 'E'])

# %%
n, k, th = docfile('ToHop2.inp')
LietKeToHop(n, k, th)
# Out:
# 15
# one two three four
# one two three five
# one two three six
# one two four five
# one two four six
# one two five six
# one three four five
# one three four six
# one three five six
# one four five six
# two three four five
# two three four six
# two three five six
# two four five six
# three four five six

# %%
n, k, th = docfile('ToHop1.inp')
LietKeToHop(n, k, th)
# Out:
# 10
# A B C
# A B D
# A B E
# A C D
# A C E
# A D E
# B C D
# B C E
# B D E
# C D E

# %% [markdown]
# ## Kết thúc
