# %% [markdown]
# # Nhật ký bài Mã Đi Tuần

# %%
# %run MaDiTuan.py

# %%
n, x0, y0 = DocFile('MaDiTuan.inp')
print(n, x0, y0)
# Out:
# 6 1 1

# %%
LietKeMa(n, x0, y0, "find")
# Out:
# 1
#  1 20 27 10  7 18
# 28 11 36 19 26  9
# 21  2 29  8 17  6
# 12 35 14 23 32 25
#  3 22 33 30  5 16
# 34 13  4 15 24 31

# %%
n, x0, y0 = DocFile('MaDiTuan3.inp')
print(n, x0, y0)
# Out:
# 8 4 3

# %%
LietKeMa(n, x0, y0, "find")
# Out:
# 1
# 24 15 42  3 26 47 58  5
# 41  2 25 64 59  4 27 46
# 16 23 14 43 48 63  6 57
# 13 40  1 62 55 60 45 28
# 22 17 54 49 44 29 56  7
# 39 12 37 20 61 50 33 30
# 18 21 10 53 32 35  8 51
# 11 38 19 36  9 52 31 34

# %%
n, x0, y0 = DocFile('MaDiTuan2.inp')
print(n, x0, y0)
# Out:
# 3 1 1

# %%
LietKeMa(n, x0, y0, "find")
# Out:
# 0

# %% [markdown]
# ## Kết thúc
