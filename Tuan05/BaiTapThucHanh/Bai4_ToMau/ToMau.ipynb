# %% [markdown]
# # Nhật ký bài Tô Màu

# %%
# %run ToMau.py

# %%
n, city = DocFile('ToMau.inp')
print(n)
print(city)
# Out:
# 9
# {1: [2, 4, 5], 2: [1, 3], 4: [1, 3, 5, 6], 5: [1, 4, 6, 9], 3: [2, 4, 7], 7: [3], 6: [4, 5, 8, 9], 9: [5, 6], 8: [6]}

# %%
Neighbor(city, 1)
# Out:
# [2, 4, 5]

# %%
LietKeCity(n, city)
# Out:
# 3
# 1 3 6
# 2 4 7 8 9
# 5

# %%
n, city = DocFile('ToMau2.inp')
print(n)
print(city)
# Out:
# 14
# {1: [2, 3], 2: [1, 3, 4], 3: [1, 2, 4, 5], 4: [2, 3, 5], 5: [3, 4, 6, 7], 6: [5, 8], 7: [5, 8, 9, 10], 8: [6, 7], 9: [7, 11, 12], 10: [7, 11], 11: [9, 10], 12: [9, 13], 13: [12, 14], 14: [13]}

# %%
LietKeCity(n, city)
# Out:
# 3
# 1 4 6 7 11 12 14
# 2 5 8 9 10 13
# 3

# %% [markdown]
# ## Kết thúc
