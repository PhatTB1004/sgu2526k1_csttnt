# %% [markdown]
# # Nhật ký Bài Hoán vị

# %%
# %run HoanVi.py

# %%
n, hv = docfile("HoanVi1.inp")
print(n, hv)
# Out:
# 3 ['F', 'B', 'A']

# %%
LietKeHoanVi(n, hv)
# Out:
# 6
# F B A
# F A B
# B F A
# B A F
# A F B
# A B F

# %%
n, hv = docfile("HoanVi2.inp")
print(n, hv)
# Out:
# 4 ['N', 'O', 'P', 'Q']

# %%
LietKeHoanVi(n, hv)
# Out:
# 24
# N O P Q
# N O Q P
# N P O Q
# N P Q O
# N Q O P
# N Q P O
# O N P Q
# O N Q P
# O P N Q
# O P Q N
# O Q N P
# O Q P N
# P N O Q
# P N Q O
# P O N Q
# P O Q N
# P Q N O
# P Q O N
# Q N O P
# Q N P O
# Q O N P
# Q O P N
# Q P N O
# Q P O N

# %% [markdown]
# ## Kết thúc
